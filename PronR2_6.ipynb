# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
df = pd.read_csv('RFP_20213TSSR.csv', sep=',', encoding = 'utf-8')
#list(df.columns)

# %%
isr = df.plot.bar(x='Modelo', y='ISR', rot=0,
                  figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                 title='Impuesto Sobre la Renta')

# %%
iva = df.plot.bar(x='Modelo', y='IVA', rot=0, 
                  figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                  title='Impuesto al Valor Agregado')

# %%
iepsg = df.plot.bar(x='Modelo', y='IEPS Gasolinas', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                   title='IEPS Gasolinas y Diesel')

# %%
iepsb = df.plot.bar(x='Modelo', y='IEPS Bebidas Alcoholicas', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                  title='IEPS Bebidas Alcohólicas' )

# %%
iepsc = df.plot.bar(x='Modelo', y='IEPS Cervezas', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                   title='IEPS Cervezas')

# %%
iepst = df.plot.bar(x='Modelo', y='IEPS Tabacos', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                  title='IEPS Tabacos' )

# %%
iepsbs = df.plot.bar(x='Modelo', y='IEPS Bebidas Saborizadas', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                  title='IEPS Bebidas Saborizadas' )

# %%
iepsa = df.plot.bar(x='Modelo', y='IEPS Alimentos', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                  title='IEPS Alimentos' )

# %%
imp = df.plot.bar(x='Modelo', y='Impuesto a la importacion', rot=0, 
                    figsize=(10,6), #color=['blue','blue','blue','blue','blue','black'],
                  title='Impuesto a la importacion' )

# %%
petro = df.plot.bar(x='Modelo', y='Ingresos Petroleros', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                  title='Ingresos Petroleros' )

# %% [markdown]
# ## Conclusión

# %%
rfp = df.plot.bar(x='Modelo', y='RFP', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                  title='Recaudación Federal Participable' )

# %%
rfp2 = df.plot.bar(x='Modelo', y='RFP_S', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                  title='Recaudación Federal Participable (Subseries)' )

# %%
ssr = df.plot.bar(x='Modelo', y='SSR', rot=0, 
                    figsize=(9,5), #color=['blue','blue','blue','blue','blue','black'],
                  title='Suma de los Errores Cuadrados' )
